# %%
import pandas

# %%
pandas.read_csv('Feb14GS.csv')
# Out:
#                 nameOfIssuer titleOfClass      cusip   value  \
# 0          1 800 FLOWERS COM          CMN  68243Q106     262
# 1            1ST SOURCE CORP          CMN  336901103     707
# 2            1ST SOURCE CORP          CMN  336901103    1223
# 3           3-D SYS CORP DEL          CMN  88554D205   13091
# 4           3-D SYS CORP DEL          CMN  88554D205   20500
# 5           3-D SYS CORP DEL          CMN  88554D205   23414
# 6           3-D SYS CORP DEL          CMN  88554D205    1598
# 7                      3M CO          CMN  88579Y101  201016
# 8                      3M CO          CMN  88579Y101   69340
# 9                      3M CO          CMN  88579Y101   51472
# 10                     3M CO          CMN  88579Y101   65721
# 11                     3M CO          CMN  88579Y101     224
# 12                     3M CO          CMN  88579Y101     158
# 13                 51JOB INC          CMN  316827104      82
# ...
